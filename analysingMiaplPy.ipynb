# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from mintpy.objects import ifgramStack
from mintpy.utils import plot as pp, utils as ut
from mintpy import view, plot_network

# %%
import subprocess

cmd = [
    "view.py",
    "/insar-data/Miaplpy_Tocantins/miaplpy/network_single_reference/velocity.h5",
    "--dem", "/insar-data/Miaplpy_Tocantins/miaplpy/network_single_reference/inputs/geometryRadar.h5",
    "--shade-exag", "0.05",
    "--figsize", "12", "12",
    "--save",
    "-m", "/insar-data/Miaplpy_Tocantins/miaplpy/maskPS.h5",
    "--notitle", "--notick", "--noaxis", "--noverbose"
]

subprocess.run(cmd)
# Out:
# view.py /insar-data/Miaplpy_Tocantins/miaplpy/network_single_reference/velocity.h5 --dem /insar-data/Miaplpy_Tocantins/miaplpy/network_single_reference/inputs/geometryRadar.h5 --shade-exag 0.05 --figsize 12 12 --save -m /insar-data/Miaplpy_Tocantins/miaplpy/maskPS.h5 --notitle --notick --noaxis --noverbose
# Figure(1320x1200)
# CompletedProcess(args=['view.py', '/insar-data/Miaplpy_Tocantins/miaplpy/network_single_reference/velocity.h5', '--dem', '/insar-data/Miaplpy_Tocantins/miaplpy/network_single_reference/inputs/geometryRadar.h5', '--shade-exag', '0.05', '--figsize', '12', '12', '--save', '-m', '/insar-data/Miaplpy_Tocantins/miaplpy/maskPS.h5', '--notitle', '--notick', '--noaxis', '--noverbose'], returncode=0)

# %%
import subprocess

cmd = [
    "view.py",
    "/insar-data/Miaplpy_Tocantins/miaplpy/network_single_reference/geo/geo_velocity.h5",
    "--dem", "/insar-data/Miaplpy_Tocantins/miaplpy/network_single_reference/geo/geo_geometryRadar.h5",
    "--shade-exag", "0.05",
    "--figsize", "12", "12",
    "--save",
    #"-m", "/insar-data/Miaplpy_Tocantins/miaplpy/maskPS.h5",
    "--notitle", "--notick", "--noaxis", "--noverbose"
]

subprocess.run(cmd)
# Out:
# view.py /insar-data/Miaplpy_Tocantins/miaplpy/network_single_reference/geo/geo_velocity.h5 --dem /insar-data/Miaplpy_Tocantins/miaplpy/network_single_reference/geo/geo_geometryRadar.h5 --shade-exag 0.05 --figsize 12 12 --save --notitle --notick --noaxis --noverbose
# WARNING: elevation range (127.4-273.7 m) < 2 contour levels (400.0 m) --> skip plotting DEM contour and continue
# Figure(1320x1200)
# CompletedProcess(args=['view.py', '/insar-data/Miaplpy_Tocantins/miaplpy/network_single_reference/geo/geo_velocity.h5', '--dem', '/insar-data/Miaplpy_Tocantins/miaplpy/network_single_reference/geo/geo_geometryRadar.h5', '--shade-exag', '0.05', '--figsize', '12', '12', '--save', '--notitle', '--notick', '--noaxis', '--noverbose'], returncode=0)

# %%
# !view.py -h
# Out:
# usage: view.py [-h] [-n [NUM ...]] [--nosearch] [--ex [Dset ...]]
#                [--show-kept] [--noverbose]
#                [--math {square,sqrt,inverse,deg2rad,reverse,rad2deg}]
#                [-v VMIN VMAX] [-u UNIT] [--nd NO_DATA_VALUE] [--wrap]
#                [--wrap-range MIN MAX] [--interp INTERPOLATION]
#                [--alpha TRANSPARENCY] [--flip-lr] [--flip-ud] [--noflip]
#                [--nmli NUM] [--nomultilook] [--style {scatter,image}]
#                [--scatter-size SIZE] [-d DEM_FILE] [--mask-dem]
#                [--dem-noshade] [--dem-nocontour] [--dem-blend]
#                [--contour-smooth NUM] [--contour-step NUM] [--contour-lw NUM]
#                [--shade-az DEG] [--shade-alt DEG] [--shade-min MIN]
#                [--shade-max MAX] [--shade-exag NUM] [--shade-frac NUM]
#                [--base-color NUM] [--blend-mode STR] [--fontsize FONT_SIZE]
#                [--fontcolor FONT_COLOR] [--nowhitespace] [--noaxis] [--notick]
# ...
